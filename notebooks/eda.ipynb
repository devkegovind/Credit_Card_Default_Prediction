# %% [markdown]
# **IMPORT LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORT DATASET**

# %%
df = pd.read_csv(r"D:\\credit_card_int\\notebooks\\data\\archive\\UCI_Credit_Card.csv")

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...    88004.0    31237.0    15980.0    8500.0   20000.0
# 29996     -1  ...     8979.0     5190.0        0.0    1837.0    3526.0
# 29997     -1  ...    20878.0    20582.0    19357.0       0.0       0.0
# 29998      0  ...    52774.0    11855.0    48944.0   85900.0    3409.0
# 29999      0  ...    36535.0    32428.0    15313.0    2078.0    1800.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.sample(5)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 12690  12691   150000.0    1          1         2   28     -1     -1     -1
# 18782  18783   150000.0    2          1         2   29     -1     -1     -2
# 23460  23461   300000.0    2          1         2   38      0      0      2
# 13191  13192   120000.0    2          2         1   48      0      0      0
# 23254  23255   360000.0    2          1         1   43     -1      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 12690     -2  ...      -31.0      -31.0      -31.0    6546.0       0.0
# 18782     -1  ...     1298.0      359.0     6100.0       0.0       0.0
# 23460     -1  ...     3792.0    11977.0    29127.0    2318.0       0.0
# 13191      0  ...    72594.0    72008.0    74622.0    4000.0    3505.0
# 23254      0  ...    18370.0        0.0        0.0    1328.0    1637.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %% [markdown]
# **UNIVARIATE ANALYSIS**

# %%
plt.figure(figsize=(35,25))
for i in enumerate(df.columns):
    plt.subplot(6, 5, i[0]+1)
    plt.subplots_adjust(hspace=0.5, wspace=0.3)
    plt.hist(df[i[1]], bins = 10, edgecolor = 'black')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.title(i[1])
plt.show()

# %%
plt.figure(figsize=(35,25))
for i in enumerate(df.columns):
    plt.subplot(6, 5, i[0]+1)
    plt.subplots_adjust(hspace=0.5, wspace=0.3)
    plt.boxplot(df[i[1]])    
    plt.title(i[1])
plt.show()

# %%
df = df.reset_index(drop=True)
plt.figure(figsize=(35,25))
for i in enumerate(df.columns):
    plt.subplot(6,5,i[0]+1)
    plt.subplots_adjust(hspace=0.5, wspace=0.3)
    sns.kdeplot(df[i[1]])
    plt.title(i)
    #plt.xlabel('Value')
    #plt.ylabel('Frequency')
    #plt.tight_layout()
plt.show()

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %%
df = df.reset_index(drop=True)
plt.figure(figsize=(35,15))
for i in enumerate(df.columns):    
    plt.subplot(6,5,i[0]+1)
    plt.subplots_adjust(hspace=0.5, wspace=.3)
    plt.scatter(y = df[i[1]], x = df['default.payment.next.month'])
    plt.title(i[1])
   

plt.show()

# %% [markdown]
# **MULTIVARIANTE ANALYSIS**

# %%
plt.figure(figsize=(45,25))
sns.heatmap(df.corr(), annot = True, cbar=False)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(35,25))
for i in enumerate(df.columns):
    plt.subplot(6, 5, i[0]+1)
    plt.subplots_adjust(hspace=0.5, wspace=0.3)
    sns.barplot(df[i[1]])
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.title(i[1])
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
import random

# Generate marks for 10 students
marks = []
for _ in range(30):
    mark = int(random.uniform(22, 26))
    marks.append(mark)
print(marks)

'''# Print the marks
for i, mark in enumerate(marks):
    print(f"Student {i+1}: {mark}")'''
# Out:
# [23, 23, 25, 23, 23, 25, 25, 23, 24, 24, 25, 23, 25, 24, 25, 24, 23, 23, 25, 22, 24, 25, 22, 25, 24, 23, 23, 23, 22, 22]
# '# Print the marks\nfor i, mark in enumerate(marks):\n    print(f"Student {i+1}: {mark}")'
